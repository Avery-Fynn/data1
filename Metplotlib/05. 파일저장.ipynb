# %% [markdown]
# # 5. 파일 저장

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Apple SD Gothic Neo'
matplotlib.rcParams['font.size'] = 15 #글자 크기
x=[1,2,3]
y=[2,4,8]

# %%
plt.figure(facecolor='#a1c3ff', dpi=100)
plt.plot(x,y)

plt.savefig('graph.png')
